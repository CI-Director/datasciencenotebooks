# %% [markdown]
# <a href="https://codeimmersives.com"><img src = "https://www.codeimmersives.com/wp-content/uploads/2019/09/CodeImmersives_Logo_RGB_NYC_BW.png" width = 400> </a>
#
#
# <h1 align=center><font size = 5>Agenda</font></h1>

# %% [markdown]
# ###
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# 1.  [Review](#0)<br>
# 2.  [Pandas](#2)<br>
# 2.  [Exercise](#10)<br>
# 3.  [Exercise](#12)<br>
# </div>
# <hr>

# %% [markdown]
# <h2>Review</h2>

# %% [markdown]
# <h2>Exercise</h2>
# Create a horizontal bar chart using the data below.  Use an 'X'
# <code><br>
# data = { 'New York':20,
#     'California':10,
#     'Rhode Island':5,
#     'Texas': 15,
#     'California':17,
#     'Florida':8,
#     'New Hampshire':3,
#     'New Jersey':12}
# </code><br>
# <br>
# Do not use matplotlib. Hint: dataframes can use df.plot(kind = 'chart_type'). Try this out.

# %% [markdown]
# <h4>Solution</h4>

# %%
import pandas as pd
data = { 'New York':20, 
    'California':10, 
    'Rhode Island':5, 
    'Texas': 15, 
    'California':17, 
    'Florida':8, 
    'New Hampshire':3, 
    'New Jersey':12}
x = pd.DataFrame(data = data.values(), index = data.keys())
x.plot(kind = 'barh')

# %% [markdown]
# <h2>Pandas DataFrames</h2>
# We can add an index to our data frame by using the index parameter<br>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <h2>Exercise</h2>
# <br>
# Using a pandas dataframe use the dictionary below and transfer the states to the <br>
# index.<br>
# <code>
# data = { 'New York':20,
#     'California':10,
#     'Rhode Island':5,
#     'Texas': 15,
#     'California':17,
#     'Florida':8,
#     'New Hampshire':3,
#     'New Jersey':12}
# </code>

# %% [markdown]
# Print out the results of California to Florida<br>

# %% [markdown]
# <h4>Solution</h4>

# %%
x['California':'Florida']
# Out:
#                0
# California    17
# Rhode Island   5
# Texas         15
# Florida        8

# %% [markdown]
# <h4>Remember that the loc method is inclusive!!!!</h4>

# %% [markdown]
# <h2>Pandas - Add column headers</h2>
# To add a column header use the columns parameter.
# <br>

# %%
import pandas as pd
data = { 'New York':[20,15], 
    'California':[10,3], 
    'Rhode Island':[5,6], 
    'Texas': [15,3], 
    'California':[17,4], 
    'Florida':[8,9], 
    'New Hampshire':[3,4], 
    'New Jersey':[12,8]}

# %% [markdown]
# add a new column, 'votes', which is the total of the Yes and No Vote of a referendum on tax control by state:
# <br>
# <code>
# import pandas as pd
# data = { 'New York':[20,15],
#     'California':[10,3],
#     'Rhode Island':[5,6],
#     'Texas': [15,3],
#     'California':[17,4],
#     'Florida':[8,9],
#     'New Hampshire':[3,4],
#     'New Jersey':[12,8]}
# </code>

# %%
import pandas as pd
data = { 'New York':[20,15], 
    'California':[10,3], 
    'Rhode Island':[5,6], 
    'Texas': [15,3], 
    'California':[17,4], 
    'Florida':[8,9], 
    'New Hampshire':[3,4], 
    'New Jersey':[12,8]}
x['Votes'] = data.values()
x
# Out:
#                 0     Votes
# New York       20  [20, 15]
# California     17   [17, 4]
# Rhode Island    5    [5, 6]
# Texas          15   [15, 3]
# Florida         8    [8, 9]
# New Hampshire   3    [3, 4]
# New Jersey     12   [12, 8]

# %% [markdown]
# <h2>Pandas - Remove a column</h2>
# There are 2 ways to remove a column from a dataframe.<br>
# <br>
# Method 1:
# To drop a column use the drop method with the axis parameter
#
# <code>
# import pandas as pd
# data = { 'New York':[20,15],
#     'California':[10,3],
#     'Rhode Island':[5,6],
#     'Texas': [15,3],
#     'California':[17,4],
#     'Florida':[8,9],
#     'New Hampshire':[3,4],
#     'New Jersey':[12,8]}
# </code>
# NOTE: The drop is not executed in place.  You need to rename the dataframe to see<br>
#     your changes

# %%
y = x.drop(['Votes'], axis=1)
y
# Out:
#                 0
# New York       20
# California     17
# Rhode Island    5
# Texas          15
# Florida         8
# New Hampshire   3
# New Jersey     12

# %% [markdown]
# <h2>Pandas - Remove a column - Method 2</h2>
# Use the pop method to remove the column in place<br>
# <code>
# import pandas as pd
# data = { 'New York':[20,15],
#     'California':[10,3],
#     'Rhode Island':[5,6],
#     'Texas': [15,3],
#     'California':[17,4],
#     'Florida':[8,9],
#     'New Hampshire':[3,4],
#     'New Jersey':[12,8]}
# </code>

# %%
import pandas as pd
data = { 'New York':[20,15], 
    'California':[10,3], 
    'Rhode Island':[5,6], 
    'Texas': [15,3], 
    'California':[17,4], 
    'Florida':[8,9], 
    'New Hampshire':[3,4], 
    'New Jersey':[12,8]}
#x = pd.DataFrame(data = data.values(), keys = data.keys())
y = x.pop('Votes')
# Out:
#                 0
# New York       20
# California     17
# Rhode Island    5
# Texas          15
# Florida         8
# New Hampshire   3
# New Jersey     12

# %% [markdown]
# <h2>Exercise</h2>
# Take the columns yes and no ([yes,no]) and transform them from values to a percentage of the votes for each State<br>
# <code>
# import pandas as pd
# data = { 'New York':[20,15],
#     'California':[10,3],
#     'Rhode Island':[5,6],
#     'Texas': [15,3],
#     'California':[17,4],
#     'Florida':[8,9],
#     'New Hampshire':[3,4],
#     'New Jersey':[12,8]}
# <code>

# %% [markdown]
# <h4>Solution</h4>

# %%
import pandas as pd
data = { 'New York':[20,15], 
    'California':[10,3], 
    'Rhode Island':[5,6], 
    'Texas': [15,3], 
    'California':[17,4], 
    'Florida':[8,9], 
    'New Hampshire':[3,4], 
    'New Jersey':[12,8]}
x = pd.DataFrame(data =data.values(), index = data.keys())
x['Yes Votes'] = x[0]/(x[1]+x[0])*100
x['No Votes'] = x[1]/(x[0]+x[1])*100
x.pop(0)
x.pop(1)
x
# Out:
#                Yes Votes   No Votes
# New York       57.142857  42.857143
# California     80.952381  19.047619
# Rhode Island   45.454545  54.545455
# Texas          83.333333  16.666667
# Florida        47.058824  52.941176
# New Hampshire  42.857143  57.142857
# New Jersey     60.000000  40.000000

# %% [markdown]
# <h3>Exercise:
#
# Using our US_Presidents.txt file and Pandas
#
# 1) Clean the data
#
# 2) Reorder all the presidents by their index. Which is the number of president they are. Washington is 1st, Adams is 2nd, etc
#
# 3) Create columns first name, middle name, last name. If they don't have a a middle name, leave it blank
#
# 4) Add a column called term length. Which tells us how long they were in office for

# %%
import pandas as pd 
import numpy as np
pres = pd.read_csv('US_Presidents_unordered.txt')
pres = pd.DataFrame(pres)
#1 Clean the data - we recognize unwanted quotes 
pres.columns = ['Name', 'Term Start', 'Term End']
pres['Name'] = pres['Name'].map(lambda x: x.strip("'"))
pres["Term Start"] = pres["Term Start"].map(lambda x: x.strip("'"))
pres["Term End"] = pres["Term End"].map(lambda x: x.strip("'"))

#2 Reorder by index - we create a new column to store the index
pres['Pres_ind'] = pres['Name'].map(lambda x: x[0:2].strip(".")).astype(int)
pres = pres.sort_values('Pres_ind')
pres

#3 Columns for first, middle, last name 


#4 Term Length 
pres['Term Start'] = pd.to_datetime(pres['Term Start'])
pres['Term End'] = pd.to_datetime(pres['Term End'])
pres['Term Length'] =  pres['Term End'].subtract(pres['Term Start'])
